# %%
import os
import sys
module_path = "../../../"
if module_path not in sys.path:
    sys.path.append(module_path)
# !pip install -r ../../../requirements.txt

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

from robustness_metrics.projects.revisiting_calibration import display
from robustness_metrics.projects.revisiting_calibration import figures
from robustness_metrics.projects.revisiting_calibration import plotting

plotting.set_seaborn_theme()
mpl.rcParams['figure.dpi'] = 150
mpl.rcParams['savefig.dpi'] = 150

# %load_ext autoreload
# %autoreload 2

# %%
parent_dir = '/shared/rsaas/marten4/'
df_main = pd.read_csv(parent_dir+ 'df_main_2021_06_15.zip', index_col="index", compression="zip")
df_reliability = pd.read_csv(parent_dir + 'df_reliability_2021_06_15.zip', index_col="index", compression="zip")

# %% [markdown]
# ## CLIP on ImageNet-C per distortion

# %%
mask = df_main.ModelFamily == 'clip'
mask &= df_main.ModelName == 'clip_vit_b32'  
mask &= df_main.Metric == 'accuracy'
mask &= df_main.rescaling_method == 'none' 
mask &= df_main.DatasetName == "imagenet(split='validation[20%:]')"
imagenet_acc = df_main[mask].MetricValue.values[0]
print(f"CLIP ViT-B/32 ImageNet-Val Accuracy: {imagenet_acc}")
# Out:
# CLIP ViT-B/32 ImageNet-Val Accuracy: 0.5978999733924865

# %%
mask = df_main.ModelFamily == 'clip'
mask &= df_main.ModelName == 'clip_vit_b32'  # 'clip_r101', 'clip_r50', 'clip_r50x4'
mask &= df_main.Metric == 'accuracy'
mask &= df_main.rescaling_method == 'none' # temperature scaling only affects confidence, not accuracy
mask &= df_main.DatasetName.str.contains('imagenet_c')
df = df_main[mask]  # 75 rows = 15 distortions * 5 serverties

# %%
def plot(df_main):
    mid = len(df.corruption_type.unique()) // 2
    distortions = df.corruption_type.unique()
    severities = df.severity.unique()

    for dist in [distortions[:mid], distortions[mid:]]:
        rows = []
        for distortion_name in dist:
                row = [distortion_name]
                for severity in severities:
                    mask = (df.severity == severity) & (df.corruption_type == distortion_name)
                    df[mask].MetricValue.values[0]
                    acc = df[mask].MetricValue.values[0]
                    row.append(acc)
                rows.append(row)

        columns = ["Method", "Severity 1", "Severity 2", "Severity 3", "Severity 4", "Severity 5"]
        p = pd.DataFrame(rows, columns=columns).plot(x='Method',
                kind='bar',
                stacked=False,
                rot=0,
                xlabel=" ",
                figsize=(7,1), # fontsize=12,
                ylim=(0.0,1.0));

        p.axhline(y=imagenet_acc, color='r', linestyle='--', label='No Distortion', linewidth=2);
        p.legend(bbox_to_anchor=(1.14,0.5), loc="right", borderaxespad=0); #, prop={'size': size});

        plt.rcParams["savefig.bbox"] = 'tight'
        fig = p.get_figure()
        fig.savefig('first.jpeg', dpi=300)

# %% [markdown]
# ## With different CLIP models

# %%
figures.NEW_clip_imagenet_c_per_dist.plot(df_main, ModelName='clip_r101')

# %%
figures.NEW_clip_imagenet_c_per_dist.plot(df_main, ModelName='clip_vit_b32')
